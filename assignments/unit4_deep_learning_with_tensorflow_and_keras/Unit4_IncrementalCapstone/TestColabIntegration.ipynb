# %%
# === COLAB BOOTSTRAP ===
BOOTSTRAP_URL = 'https://raw.githubusercontent.com/rlogwood/fs-ml-lib/main/colab_bootstrap.py'
import urllib.request; exec(urllib.request.urlopen(BOOTSTRAP_URL).read().decode())
# === END BOOTSTRAP ===
# to force reload after code changes use force_refresh=True
upload_lib(force_refresh=False)
# Out:
# Not in Colab, using local lib files

# %%
# Imports
import lib.text_util as tu
import lib.wrangler as wr
import lib.data_cleaner as dc
import lib.analyzer as da
import lib.corr_analysis as ca
import lib.utility as utl
import lib.data_downloader as ddl

# Reload modules after code changes
reload_lib_modules()
# %%
print("Testing text_util.demo_text_print():")
tu.demo_text_print()

# %%
tu.styled_display("This is a direct styled_display test", color=tu.Color.GREEN)
print(tu.bold_text("This should be plain text in a notebook to avoid invisible ANSI codes"))
# Out:
#   ✓ Reloaded lib.text_util
#   ✓ Reloaded lib.wrangler
#   ✓ Reloaded lib.data_cleaner
#   ✓ Reloaded lib.utility
#   ✓ Reloaded lib.analyzer
#   ✓ Reloaded lib.corr_analysis
#   ✓ Reloaded lib.data_downloader
# Testing text_util.demo_text_print():
# Running as a notebook:True
# Running inside in pycharm:False
# Running inside a pycharm notebook:False
# styled_display uses HTML for styling text output.
# Show Red
# Show Bold
# Show Combo Yellow, Italic, Bold
# Show Bold and Blue
# <div style="font-size: 20px; color: orange; display: block; clear: both;"><b>Show Styled</b></div>
# <div style="font-size: 20px; color: green; display: block; clear: both;"><b>This is a direct styled_display test</b></div>
# This should be plain text in a notebook to avoid invisible ANSI codes
